# %%
# !pip install -q deeplake==3.9.52 onedrivedownloader
# !git clone https://github.com/nqh-tq-32052503/NeurIPS2025-LEAR.git
# %cd /kaggle/working/NeurIPS2025-LEAR
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 643.4/643.4 kB 17.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 96.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.6/18.6 MB 94.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 64.1 MB/s eta 0:00:00
#   Building wheel for deeplake (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# s3fs 2025.3.0 requires fsspec==2025.3.0.*, but you have fsspec 2025.10.0 which is incompatible.
# ypy-websocket 0.8.4 requires aiofiles<23,>=22.1.0, but you have aiofiles 25.1.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# ibis-framework 9.5.0 requires toolz<1,>=0.11, but you have toolz 1.1.0 which is incompatible.
# gradio 5.38.1 requires aiofiles<25.0,>=22.0, but you have aiofiles 25.1.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.6.3 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Cloning into 'NeurIPS2025-LEAR'...
# remote: Enumerating objects: 519, done.
# remote: Counting objects: 100% (519/519), done.
# remote: Compressing objects: 100% (366/366), done.
# remote: Total 519 (delta 191), reused 421 (delta 112), pack-reused 0 (from 0)
# Receiving objects: 100% (519/519), 6.69 MiB | 39.61 MiB/s, done.
# Resolving deltas: 100% (191/191), done.
# /kaggle/working/NeurIPS2025-LEAR

# %%
import copy
origin_params = {
    "list_datasets" : "seq-cifar100,seq-cifar100,seq-cifar100",
    "dataset" : "seq-cifar100",
    "ncls_per_task" : 5,
    "model" : "LEAR",
    "lr" : 0.03,
    "batch_size" : 32,
    "n_epochs" : 15,
    "num_workers" : 8,
    "backbone" : "lear",
    "transform_type" : "weak",
    "use_bilora" : 1
}

list1 = ["local", "both"]
list2 = ["separate", "aggregate"]
list3 = [0, 1]
combinations = [(x, y, z) for x in list1 for y in list2 for z in list3]

#     "apply_bilora_for" : "local",
#    "bilora_mode" : "aggregate",
#    "skip_task_0" : 0

list_params = []
for combination in combinations:
    params = copy.deepcopy(origin_params)
    params["apply_bilora_for"] = combination[0]
    params["bilora_mode"] = combination[1]
    params["skip_task_0"] = combination[2]
    list_params.append(params)

# %%
list_cmds = []
for params in list_params:
    cmd = "python main_domain.py"
    for key in params:
        param_cmd = f" --{key} {params[key]}"
        cmd += param_cmd
    list_cmds.append(cmd)

# %%
import os

for cmd in list_cmds:
    try:
        print("[INFO CMD] Running: ", cmd)    
        os.system(cmd)
    except Exception as e:
        print(e)
# Out:
# [INFO CMD] Running:  python main_domain.py --list_datasets seq-cifar100,seq-cifar100,seq-cifar100 --dataset seq-cifar100 --ncls_per_task 5 --model LEAR --lr 0.03 --batch_size 32 --n_epochs 15 --num_workers 8 --backbone lear --transform_type weak --use_bilora 1 --apply_bilora_for local --bilora_mode separate --skip_task_0 0
# [INFO] 10-Jan-26 17:52:09 - Running Mammoth! on e079c60788b6. (if you see this message more than once, you are probably importing something wrong)
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# [INFO] 10-Jan-26 17:52:19 - NumExpr defaulting to 4 threads.
# /usr/local/lib/python3.11/dist-packages/deeplake/util/check_latest_version.py:32: UserWarning: A newer version of deeplake (4.4.4) is available. It's recommended that you update to the latest version using `pip install -U deeplake`.
#   warnings.warn(
# [WARNING] 10-Jan-26 17:52:22 - Trying to load default configuration for model LEAR but no configuration file found in None.
# [WARNING] 10-Jan-26 17:52:22 - Default configuration file not found for dataset seq-cifar100. Using the defaults specified in the dataset class (if available).
# [INFO] 10-Jan-26 17:52:22 - `lr_scheduler` set to multisteplr, overrides default from dataset.
# [INFO] 10-Jan-26 17:52:22 - Using device cuda:0
# Loading dataset: seq-cifar100
# Loading dataset: seq-cifar100
# Loading dataset: seq-cifar100
# [INFO] 10-Jan-26 17:52:22 - `wandb_entity` and `wandb_project` not set. Disabling wandb.
# [WARNING] 10-Jan-26 17:52:22 - Label noise is not available with multi-label datasets. If this is not multi-label, ignore this warning.
# [INFO] 10-Jan-26 17:52:24 - Loading pretrained weights from Hugging Face hub (timm/vit_base_patch16_224.augreg2_in21k_ft_in1k)
# [INFO] 10-Jan-26 17:52:27 - [timm/vit_base_patch16_224.augreg2_in21k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# [INFO] 10-Jan-26 17:52:27 - Missing keys (head.weight, head.bias) discovered while loading pretrained weights. This is expected if model is being adapted.
# [INFO] 10-Jan-26 17:52:28 - Loading pretrained weights from Hugging Face hub (timm/vit_base_patch16_224.augreg2_in21k_ft_in1k)
# [INFO] 10-Jan-26 17:52:28 - [timm/vit_base_patch16_224.augreg2_in21k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# [INFO] 10-Jan-26 17:52:28 - Missing keys (head.weight, head.bias) discovered while loading pretrained weights. This is expected if model is being adapted.
# [INFO] 10-Jan-26 17:52:29 - Using backbone: lear
# Using LEAR as backbone
# Use BiLORA:  True
# Apply BiLORA for:  local
# Namespace(dataset='seq-cifar100', model='LEAR', backbone='lear', load_best_args=False, dataset_config=None, model_config='default', list_datasets='seq-cifar100,seq-cifar100,seq-cifar100', transform_type='weak', ncls_per_task=5, use_bilora=1, apply_bilora_for='local', skip_task_0=0, bilora_mode='separate', num_classes=100, seed=None, permute_classes=False, base_path='./data/', results_path='results/', device=device(type='cuda', index=0), notes=None, eval_epochs=None, non_verbose=False, disable_log=False, num_workers=8, enable_other_metrics=False, debug_mode=False, inference_only=False, code_optimization=0, distributed='no', savecheck=None, save_checkpoint_mode='safe', loadcheck=None, ckpt_name=None, start_from=None, stop_after=None, wandb_name=None, wandb_entity=None, wandb_project=None, lr=0.03, batch_size=32, label_perc=1.0, label_perc_by_class=1.0, joint=0, eval_future=False, validation=None, validation_mode='current', fitting_mode='epochs', early_stopping_patience=5, early_stopping_metric='loss', early_stopping_freq=1, early_stopping_epsilon=1e-06, n_epochs=15, n_iters=None, optimizer='sgd', optim_wd=0.0, optim_mom=0.0, optim_nesterov=False, drop_last=False, lr_scheduler='multisteplr', scheduler_mode='epoch', lr_milestones=[35, 45], sched_multistep_lr_gamma=0.1, noise_type='symmetric', noise_rate=0.0, disable_noisy_labels_cache=False, cache_path_noisy_labels='noisy_labels', conf_jobnum='24609d3d-0d35-4115-b70a-bc258a6b8e77', conf_timestamp='2026-01-10 17:52:22.754584', conf_host='e079c60788b6', conf_git_hash='d9141df2a3954ab461ad96da8cee30a4693fe2d0', minibatch_size=32, nowand=1)
# begin task 1, dataset:seq-cifar100
# 100%|██████████| 169M/169M [00:04<00:00, 34.9MB/s]
# target classes:  [80, 17, 38, 75, 20]
# [INFO] 10-Jan-26 17:52:37 - Using 8 workers for the dataloader.
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# target classes:  [80, 17, 38, 75, 20]
# [INFO] 10-Jan-26 17:52:38 - Using 8 workers for the dataloader.
# Applying BiLORA technique for current task:  0  at index:  0
# Task 1 - Epoch 15: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1170/1170 [15:04<00:00,  1.29it/s, loss_ce=0.00476, loss_nor=-0.0323, lr=0.03, ep/h=59.9]
# Calculate distribution for task 1:  78%|███████▊  | 78/100 [00:14<00:04,  5.20it/s]
# choose experts for evaluate: [1]
# Evaluating Task 1:  20%|███████████████████▌                                                                              | 3/15 [00:01<00:07,  1.61it/s, acc_task_1=97.9]
# Accuracy for 1 task(s): 	 [Class-IL]: 97.92 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [97.91666666666666] | Task-IL [0]
# Applying BiLORA technique for current task:  1  at index:  0
# Applying BiLORA technique for current task:  1  at index:  0
# Applying BiLORA technique for current task:  1  at index:  0
# begin task 2, dataset:seq-cifar100
# target classes:  [28, 89, 12, 31, 23]
# [INFO] 10-Jan-26 18:08:02 - Using 8 workers for the dataloader.
# target classes:  [28, 89, 12, 31, 23]
# [INFO] 10-Jan-26 18:08:03 - Using 8 workers for the dataloader.
# Choose params for task 2: 100%|██████████| 50/50 [00:10<00:00,  4.99it/s, distances=[0.56]]
# load expert 1 parameters
# Create new expert 2
# Applying BiLORA technique for current task:  1  at index:  0
# Task 2 - Epoch 15: 100%|██████████████████████████████████████████████████████| 1170/1170 [17:04<00:00,  1.14it/s, loss_ce=0.000225, loss_kd=-3.14, loss_nor=-0.0299, loss_mi=0.098, lr=0.03, ep/h=53.1]
# Calculate distribution for task 2:  78%|███████▊  | 78/100 [00:15<00:04,  5.19it/s]
# Choose expert for evaluate: 100%|████████████████████████████████████████████████████████████████████████| 30/30 [00:06<00:00,  4.51it/s, task 2=2, distance=[4.08, 1.73]]
# Evaluating:   0%|                                                                                                                                  | 0/30 [00:00<?, ?it/s]
# choose experts for evaluate: [2, 2]
# Evaluating Task 1:  10%|██████████                                                                                           | 3/30 [00:01<00:15,  1.77it/s, acc_task_1=0]
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Evaluating Task 2:  20%|███████████████████▊                                                                               | 6/30 [00:03<00:14,  1.62it/s, acc_task_2=100]
# Accuracy for 2 task(s): 	 [Class-IL]: 50.0 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [0.0, 100.0] | Task-IL [0, 0]
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# begin task 3, dataset:seq-cifar100
# target classes:  [40, 92, 23, 80, 27]
# [INFO] 10-Jan-26 18:25:46 - Using 8 workers for the dataloader.
# target classes:  [40, 92, 23, 80, 27]
# [INFO] 10-Jan-26 18:25:47 - Using 8 workers for the dataloader.
# Choose params for task 3: 100%|██████████| 50/50 [00:10<00:00,  4.95it/s, distances=[0.57, 4.19]]
# load expert 1 parameters
# Create new expert 3
# Applying BiLORA technique for current task:  2  at index:  0
# Task 3 - Epoch 15: 100%|████████████████████████████████████████████████████| 1170/1170 [17:05<00:00,  1.14it/s, loss_ce=0.000857, loss_kd=-0.241, loss_nor=-0.0261, loss_mi=0.0331, lr=0.03, ep/h=52.6]
# Calculate distribution for task 3:  78%|███████▊  | 78/100 [00:15<00:04,  5.18it/s]
# Choose expert for evaluate: 100%|█████████████████████████████████████████████████████████████████| 45/45 [00:10<00:00,  4.45it/s, task 3=1, distance=[2.17, 11.69, 2.22]]
# Evaluating:   0%|                                                                                                                                  | 0/45 [00:00<?, ?it/s]
# choose experts for evaluate: [1, 1, 1]
# Evaluating Task 1:   7%|██████▌                                                                                           | 3/45 [00:01<00:24,  1.71it/s, acc_task_1=97.9]
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Evaluating Task 2:  13%|█████████████▍                                                                                       | 6/45 [00:03<00:23,  1.64it/s, acc_task_2=0]
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Evaluating Task 3:  20%|███████████████████▌                                                                              | 9/45 [00:05<00:23,  1.54it/s, acc_task_3=20.8]
# Accuracy for 3 task(s): 	 [Class-IL]: 39.58 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [97.91666666666666, 0.0, 20.833333333333336] | Task-IL [0, 0, 0]
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# System stats:
# 	Initial CPU memory usage: 2760.63 MB
# 	Average CPU memory usage: 3823.64 MB
# 	Final CPU memory usage: 4395.50 MB
# 	Max CPU memory usage: 4379.71 MB
# 	Initial GPU 0 memory usage: 1082.00 MB
# 	Average GPU 0 memory usage: 6188.00 MB
# 	Final GPU 0 memory usage: 6188.00 MB
# 	Max GPU 0 memory usage: 6188.00 MB
# Logging results and arguments in ./data/results/class-il/seq-cifar100/LEAR/logs.pyd
# [INFO CMD] Running:  python main_domain.py --list_datasets seq-cifar100,seq-cifar100,seq-cifar100 --dataset seq-cifar100 --ncls_per_task 5 --model LEAR --lr 0.03 --batch_size 32 --n_epochs 15 --num_workers 8 --backbone lear --transform_type weak --use_bilora 1 --apply_bilora_for local --bilora_mode separate --skip_task_0 1
# [INFO] 10-Jan-26 18:43:38 - Running Mammoth! on e079c60788b6. (if you see this message more than once, you are probably importing something wrong)
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# [INFO] 10-Jan-26 18:43:41 - NumExpr defaulting to 4 threads.
# /usr/local/lib/python3.11/dist-packages/deeplake/util/check_latest_version.py:32: UserWarning: A newer version of deeplake (4.4.4) is available. It's recommended that you update to the latest version using `pip install -U deeplake`.
#   warnings.warn(
# [WARNING] 10-Jan-26 18:43:42 - Trying to load default configuration for model LEAR but no configuration file found in None.
# [WARNING] 10-Jan-26 18:43:42 - Default configuration file not found for dataset seq-cifar100. Using the defaults specified in the dataset class (if available).
# [INFO] 10-Jan-26 18:43:42 - `lr_scheduler` set to multisteplr, overrides default from dataset.
# [INFO] 10-Jan-26 18:43:42 - Using device cuda:0
# Loading dataset: seq-cifar100
# Loading dataset: seq-cifar100
# Loading dataset: seq-cifar100
# [INFO] 10-Jan-26 18:43:42 - `wandb_entity` and `wandb_project` not set. Disabling wandb.
# [WARNING] 10-Jan-26 18:43:42 - Label noise is not available with multi-label datasets. If this is not multi-label, ignore this warning.
# [INFO] 10-Jan-26 18:43:44 - Loading pretrained weights from Hugging Face hub (timm/vit_base_patch16_224.augreg2_in21k_ft_in1k)
# [INFO] 10-Jan-26 18:43:44 - [timm/vit_base_patch16_224.augreg2_in21k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# [INFO] 10-Jan-26 18:43:44 - Missing keys (head.weight, head.bias) discovered while loading pretrained weights. This is expected if model is being adapted.
# [INFO] 10-Jan-26 18:43:45 - Loading pretrained weights from Hugging Face hub (timm/vit_base_patch16_224.augreg2_in21k_ft_in1k)
# [INFO] 10-Jan-26 18:43:45 - [timm/vit_base_patch16_224.augreg2_in21k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# [INFO] 10-Jan-26 18:43:46 - Missing keys (head.weight, head.bias) discovered while loading pretrained weights. This is expected if model is being adapted.
# [INFO] 10-Jan-26 18:43:46 - Using backbone: lear
# Using LEAR as backbone
# Use BiLORA:  True
# Apply BiLORA for:  local
# Namespace(dataset='seq-cifar100', model='LEAR', backbone='lear', load_best_args=False, dataset_config=None, model_config='default', list_datasets='seq-cifar100,seq-cifar100,seq-cifar100', transform_type='weak', ncls_per_task=5, use_bilora=1, apply_bilora_for='local', skip_task_0=1, bilora_mode='separate', num_classes=100, seed=None, permute_classes=False, base_path='./data/', results_path='results/', device=device(type='cuda', index=0), notes=None, eval_epochs=None, non_verbose=False, disable_log=False, num_workers=8, enable_other_metrics=False, debug_mode=False, inference_only=False, code_optimization=0, distributed='no', savecheck=None, save_checkpoint_mode='safe', loadcheck=None, ckpt_name=None, start_from=None, stop_after=None, wandb_name=None, wandb_entity=None, wandb_project=None, lr=0.03, batch_size=32, label_perc=1.0, label_perc_by_class=1.0, joint=0, eval_future=False, validation=None, validation_mode='current', fitting_mode='epochs', early_stopping_patience=5, early_stopping_metric='loss', early_stopping_freq=1, early_stopping_epsilon=1e-06, n_epochs=15, n_iters=None, optimizer='sgd', optim_wd=0.0, optim_mom=0.0, optim_nesterov=False, drop_last=False, lr_scheduler='multisteplr', scheduler_mode='epoch', lr_milestones=[35, 45], sched_multistep_lr_gamma=0.1, noise_type='symmetric', noise_rate=0.0, disable_noisy_labels_cache=False, cache_path_noisy_labels='noisy_labels', conf_jobnum='92d31e8e-bd55-4e59-896d-1bae0f2c8b1d', conf_timestamp='2026-01-10 18:43:42.827315', conf_host='e079c60788b6', conf_git_hash='d9141df2a3954ab461ad96da8cee30a4693fe2d0', minibatch_size=32, nowand=1)
# begin task 1, dataset:seq-cifar100
# target classes:  [7, 2, 70, 93, 89]
# [INFO] 10-Jan-26 18:43:48 - Using 8 workers for the dataloader.
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# target classes:  [7, 2, 70, 93, 89]
# [INFO] 10-Jan-26 18:43:49 - Using 8 workers for the dataloader.
# Task 1 - Epoch 15: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1170/1170 [11:25<00:00,  1.71it/s, loss_ce=5.53e-5, loss_nor=-0.0323, lr=0.03, ep/h=79.5]
# Calculate distribution for task 1:  78%|███████▊  | 78/100 [00:14<00:04,  5.32it/s]
# Evaluating:   0%|                                                                                                                                  | 0/15 [00:00<?, ?it/s]
# choose experts for evaluate: [1]
# Evaluating Task 1:  20%|████████████████████                                                                                | 3/15 [00:01<00:07,  1.55it/s, acc_task_1=99]
# Accuracy for 1 task(s): 	 [Class-IL]: 98.96 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [98.95833333333334] | Task-IL [0]
# Applying BiLORA technique for current task:  1  at index:  0
# Applying BiLORA technique for current task:  1  at index:  0
# Applying BiLORA technique for current task:  1  at index:  0
# begin task 2, dataset:seq-cifar100
# target classes:  [67, 9, 69, 75, 56]
# [INFO] 10-Jan-26 18:55:33 - Using 8 workers for the dataloader.
# target classes:  [67, 9, 69, 75, 56]
# [INFO] 10-Jan-26 18:55:34 - Using 8 workers for the dataloader.
# Choose params for task 2: 100%|██████████| 50/50 [00:10<00:00,  5.00it/s, distances=[1.0]]
# load expert 1 parameters
# Create new expert 2
# Applying BiLORA technique for current task:  1  at index:  0
# Task 2 - Epoch 15: 100%|██████████████████████████████████████████████████████| 1170/1170 [16:55<00:00,  1.15it/s, loss_ce=0.000445, loss_kd=-3.29, loss_nor=-0.0315, loss_mi=0.102, lr=0.03, ep/h=53.7]
# Calculate distribution for task 2:  78%|███████▊  | 78/100 [00:15<00:04,  5.19it/s]
# Choose expert for evaluate: 100%|█████████████████████████████████████████████████████████████████████████| 30/30 [00:06<00:00,  4.48it/s, task 2=2, distance=[5.1, 2.05]]
# Evaluating:   0%|                                                                                                                                  | 0/30 [00:00<?, ?it/s]
# choose experts for evaluate: [2, 2]
# Evaluating Task 1:  10%|██████████                                                                                           | 3/30 [00:01<00:15,  1.76it/s, acc_task_1=0]
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Evaluating Task 2:  20%|███████████████████▌                                                                              | 6/30 [00:03<00:15,  1.59it/s, acc_task_2=95.8]
# Accuracy for 2 task(s): 	 [Class-IL]: 47.92 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [0.0, 95.83333333333334] | Task-IL [0, 0]
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# begin task 3, dataset:seq-cifar100
# target classes:  [97, 9, 41, 13, 72]
# [INFO] 10-Jan-26 19:13:08 - Using 8 workers for the dataloader.
# target classes:  [97, 9, 41, 13, 72]
# [INFO] 10-Jan-26 19:13:09 - Using 8 workers for the dataloader.
# Choose params for task 3: 100%|██████████| 50/50 [00:10<00:00,  4.98it/s, distances=[0.88, 0.9]]
# load expert 1 parameters
# Create new expert 3
# Applying BiLORA technique for current task:  2  at index:  0
# Task 3 - Epoch 15: 100%|███████████████████████████████████████████████████████| 1170/1170 [17:05<00:00,  1.14it/s, loss_ce=0.00226, loss_kd=-0.0918, loss_nor=-0.0255, loss_mi=0.067, lr=0.03, ep/h=53]
# Calculate distribution for task 3:  78%|███████▊  | 78/100 [00:15<00:04,  5.18it/s]
# Choose expert for evaluate: 100%|███████████████████████████████████████████████████████████████████| 45/45 [00:10<00:00,  4.36it/s, task 3=3, distance=[3.9, 2.66, 2.08]]
# Evaluating:   0%|                                                                                                                                  | 0/45 [00:00<?, ?it/s]
# choose experts for evaluate: [3, 3, 3]
# Evaluating Task 1:   7%|██████▋                                                                                              | 3/45 [00:01<00:24,  1.70it/s, acc_task_1=0]
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# Evaluating Task 2:  13%|█████████████▎                                                                                      | 6/45 [00:03<00:23,  1.64it/s, acc_task_2=24]
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# Evaluating Task 3:  20%|████████████████████                                                                                | 9/45 [00:05<00:23,  1.53it/s, acc_task_3=99]
# Accuracy for 3 task(s): 	 [Class-IL]: 40.97 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [0.0, 23.958333333333336, 98.95833333333334] | Task-IL [0, 0, 0]
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# System stats:
# 	Initial CPU memory usage: 2647.90 MB
# 	Average CPU memory usage: 3649.23 MB
# 	Final CPU memory usage: 4204.41 MB
# 	Max CPU memory usage: 4204.41 MB
# 	Initial GPU 0 memory usage: 1082.00 MB
# 	Average GPU 0 memory usage: 6214.00 MB
# 	Final GPU 0 memory usage: 6216.00 MB
# 	Max GPU 0 memory usage: 6214.00 MB
# Logging results and arguments in ./data/results/class-il/seq-cifar100/LEAR/logs.pyd
# [INFO CMD] Running:  python main_domain.py --list_datasets seq-cifar100,seq-cifar100,seq-cifar100 --dataset seq-cifar100 --ncls_per_task 5 --model LEAR --lr 0.03 --batch_size 32 --n_epochs 15 --num_workers 8 --backbone lear --transform_type weak --use_bilora 1 --apply_bilora_for local --bilora_mode aggregate --skip_task_0 0
# [INFO] 10-Jan-26 19:31:00 - Running Mammoth! on e079c60788b6. (if you see this message more than once, you are probably importing something wrong)
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# [INFO] 10-Jan-26 19:31:03 - NumExpr defaulting to 4 threads.
# /usr/local/lib/python3.11/dist-packages/deeplake/util/check_latest_version.py:32: UserWarning: A newer version of deeplake (4.4.4) is available. It's recommended that you update to the latest version using `pip install -U deeplake`.
#   warnings.warn(
# [WARNING] 10-Jan-26 19:31:05 - Trying to load default configuration for model LEAR but no configuration file found in None.
# [WARNING] 10-Jan-26 19:31:05 - Default configuration file not found for dataset seq-cifar100. Using the defaults specified in the dataset class (if available).
# [INFO] 10-Jan-26 19:31:05 - `lr_scheduler` set to multisteplr, overrides default from dataset.
# [INFO] 10-Jan-26 19:31:05 - Using device cuda:0
# Loading dataset: seq-cifar100
# Loading dataset: seq-cifar100
# Loading dataset: seq-cifar100
# [INFO] 10-Jan-26 19:31:05 - `wandb_entity` and `wandb_project` not set. Disabling wandb.
# [WARNING] 10-Jan-26 19:31:05 - Label noise is not available with multi-label datasets. If this is not multi-label, ignore this warning.
# [INFO] 10-Jan-26 19:31:06 - Loading pretrained weights from Hugging Face hub (timm/vit_base_patch16_224.augreg2_in21k_ft_in1k)
# [INFO] 10-Jan-26 19:31:06 - [timm/vit_base_patch16_224.augreg2_in21k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# [INFO] 10-Jan-26 19:31:06 - Missing keys (head.weight, head.bias) discovered while loading pretrained weights. This is expected if model is being adapted.
# [INFO] 10-Jan-26 19:31:08 - Loading pretrained weights from Hugging Face hub (timm/vit_base_patch16_224.augreg2_in21k_ft_in1k)
# [INFO] 10-Jan-26 19:31:08 - [timm/vit_base_patch16_224.augreg2_in21k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# [INFO] 10-Jan-26 19:31:08 - Missing keys (head.weight, head.bias) discovered while loading pretrained weights. This is expected if model is being adapted.
# [INFO] 10-Jan-26 19:31:08 - Using backbone: lear
# Using LEAR as backbone
# Use BiLORA:  True
# Apply BiLORA for:  local
# Namespace(dataset='seq-cifar100', model='LEAR', backbone='lear', load_best_args=False, dataset_config=None, model_config='default', list_datasets='seq-cifar100,seq-cifar100,seq-cifar100', transform_type='weak', ncls_per_task=5, use_bilora=1, apply_bilora_for='local', skip_task_0=0, bilora_mode='aggregate', num_classes=100, seed=None, permute_classes=False, base_path='./data/', results_path='results/', device=device(type='cuda', index=0), notes=None, eval_epochs=None, non_verbose=False, disable_log=False, num_workers=8, enable_other_metrics=False, debug_mode=False, inference_only=False, code_optimization=0, distributed='no', savecheck=None, save_checkpoint_mode='safe', loadcheck=None, ckpt_name=None, start_from=None, stop_after=None, wandb_name=None, wandb_entity=None, wandb_project=None, lr=0.03, batch_size=32, label_perc=1.0, label_perc_by_class=1.0, joint=0, eval_future=False, validation=None, validation_mode='current', fitting_mode='epochs', early_stopping_patience=5, early_stopping_metric='loss', early_stopping_freq=1, early_stopping_epsilon=1e-06, n_epochs=15, n_iters=None, optimizer='sgd', optim_wd=0.0, optim_mom=0.0, optim_nesterov=False, drop_last=False, lr_scheduler='multisteplr', scheduler_mode='epoch', lr_milestones=[35, 45], sched_multistep_lr_gamma=0.1, noise_type='symmetric', noise_rate=0.0, disable_noisy_labels_cache=False, cache_path_noisy_labels='noisy_labels', conf_jobnum='74ffaaaa-96e8-4f77-9c13-81a9b626f6b1', conf_timestamp='2026-01-10 19:31:05.077139', conf_host='e079c60788b6', conf_git_hash='d9141df2a3954ab461ad96da8cee30a4693fe2d0', minibatch_size=32, nowand=1)
# begin task 1, dataset:seq-cifar100
# target classes:  [34, 40, 95, 54, 19]
# [INFO] 10-Jan-26 19:31:10 - Using 8 workers for the dataloader.
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# target classes:  [34, 40, 95, 54, 19]
# [INFO] 10-Jan-26 19:31:11 - Using 8 workers for the dataloader.
# Applying BiLORA technique for current task:  0  at index:  0
# Task 1 - Epoch 15: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1170/1170 [15:07<00:00,  1.29it/s, loss_ce=5.89e-5, loss_nor=-0.0323, lr=0.03, ep/h=60.1]
# Calculate distribution for task 1:  78%|███████▊  | 78/100 [00:15<00:04,  5.17it/s]
# choose experts for evaluate: [1]
# Evaluating Task 1:  20%|███████████████████▊                                                                               | 3/15 [00:01<00:07,  1.55it/s, acc_task_1=100]
# Accuracy for 1 task(s): 	 [Class-IL]: 100.0 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [100.0] | Task-IL [0]
# Applying BiLORA technique for current task:  1  at index:  0
# Applying BiLORA technique for current task:  1  at index:  0
# Applying BiLORA technique for current task:  1  at index:  0
# begin task 2, dataset:seq-cifar100
# target classes:  [81, 83, 3, 90, 80]
# [INFO] 10-Jan-26 19:46:38 - Using 8 workers for the dataloader.
# target classes:  [81, 83, 3, 90, 80]
# [INFO] 10-Jan-26 19:46:39 - Using 8 workers for the dataloader.
# Choose params for task 2: 100%|██████████| 50/50 [00:10<00:00,  4.95it/s, distances=[0.6]]
# load expert 1 parameters
# Create new expert 2
# Applying BiLORA technique for current task:  1  at index:  0
# Task 2 - Epoch 15: 100%|████████████████████████████████████████████████████████| 1170/1170 [17:14<00:00,  1.13it/s, loss_ce=0.0662, loss_kd=-3.06, loss_nor=-0.0278, loss_mi=0.277, lr=0.03, ep/h=52.5]
# Calculate distribution for task 2:  78%|███████▊  | 78/100 [00:15<00:04,  5.14it/s]
# Choose expert for evaluate: 100%|████████████████████████████████████████████████████████████████████████| 30/30 [00:06<00:00,  4.44it/s, task 2=2, distance=[5.75, 2.26]]
# Evaluating:   0%|                                                                                                                                  | 0/30 [00:00<?, ?it/s]
# choose experts for evaluate: [2, 2]
# Evaluating Task 1:  10%|██████████                                                                                           | 3/30 [00:01<00:16,  1.66it/s, acc_task_1=0]
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Evaluating Task 2:  20%|███████████████████▌                                                                              | 6/30 [00:03<00:15,  1.51it/s, acc_task_2=97.9]
# Accuracy for 2 task(s): 	 [Class-IL]: 48.96 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [0.0, 97.91666666666666] | Task-IL [0, 0]
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# begin task 3, dataset:seq-cifar100
# target classes:  [32, 55, 82, 29, 4]
# [INFO] 10-Jan-26 20:04:33 - Using 8 workers for the dataloader.
# target classes:  [32, 55, 82, 29, 4]
# [INFO] 10-Jan-26 20:04:34 - Using 8 workers for the dataloader.
# Choose params for task 3: 100%|██████████| 50/50 [00:10<00:00,  4.87it/s, distances=[0.58, 96.39]]
# load expert 1 parameters
# Create new expert 3
# Applying BiLORA technique for current task:  2  at index:  0
# Task 3 - Epoch 15: 100%|███████████████████████████████████████████████████████████| 1170/1170 [17:28<00:00,  1.12it/s, loss_ce=0.202, loss_kd=-2.78, loss_nor=-0.0279, loss_mi=0.396, lr=0.03, ep/h=52]
# Calculate distribution for task 3:  78%|███████▊  | 78/100 [00:15<00:04,  5.05it/s]
# Choose expert for evaluate: 100%|████████████████████████████████████████████████████████████████| 45/45 [00:10<00:00,  4.24it/s, task 3=1, distance=[2.21, 308.11, 2.33]]
# Evaluating:   0%|                                                                                                                                  | 0/45 [00:00<?, ?it/s]
# choose experts for evaluate: [1, 1, 1]
# Evaluating Task 1:   7%|██████▌                                                                                            | 3/45 [00:01<00:26,  1.59it/s, acc_task_1=100]
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Evaluating Task 2:  13%|█████████████▍                                                                                       | 6/45 [00:04<00:25,  1.54it/s, acc_task_2=0]
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Evaluating Task 3:  20%|████████████████████▏                                                                                | 9/45 [00:06<00:24,  1.44it/s, acc_task_3=0]
# Accuracy for 3 task(s): 	 [Class-IL]: 33.33 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [100.0, 0.0, 0.0] | Task-IL [0, 0, 0]
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# System stats:
# 	Initial CPU memory usage: 2649.66 MB
# 	Average CPU memory usage: 3690.35 MB
# 	Final CPU memory usage: 4319.25 MB
# 	Max CPU memory usage: 4319.19 MB
# 	Initial GPU 0 memory usage: 1082.00 MB
# 	Average GPU 0 memory usage: 6190.00 MB
# 	Final GPU 0 memory usage: 6190.00 MB
# 	Max GPU 0 memory usage: 6190.00 MB
# Logging results and arguments in ./data/results/class-il/seq-cifar100/LEAR/logs.pyd
# [INFO CMD] Running:  python main_domain.py --list_datasets seq-cifar100,seq-cifar100,seq-cifar100 --dataset seq-cifar100 --ncls_per_task 5 --model LEAR --lr 0.03 --batch_size 32 --n_epochs 15 --num_workers 8 --backbone lear --transform_type weak --use_bilora 1 --apply_bilora_for local --bilora_mode aggregate --skip_task_0 1
# [INFO] 10-Jan-26 20:22:49 - Running Mammoth! on e079c60788b6. (if you see this message more than once, you are probably importing something wrong)
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# [INFO] 10-Jan-26 20:22:52 - NumExpr defaulting to 4 threads.
# /usr/local/lib/python3.11/dist-packages/deeplake/util/check_latest_version.py:32: UserWarning: A newer version of deeplake (4.4.4) is available. It's recommended that you update to the latest version using `pip install -U deeplake`.
#   warnings.warn(
# [WARNING] 10-Jan-26 20:22:53 - Trying to load default configuration for model LEAR but no configuration file found in None.
# [WARNING] 10-Jan-26 20:22:53 - Default configuration file not found for dataset seq-cifar100. Using the defaults specified in the dataset class (if available).
# [INFO] 10-Jan-26 20:22:53 - `lr_scheduler` set to multisteplr, overrides default from dataset.
# [INFO] 10-Jan-26 20:22:53 - Using device cuda:0
# Loading dataset: seq-cifar100
# Loading dataset: seq-cifar100
# Loading dataset: seq-cifar100
# [INFO] 10-Jan-26 20:22:53 - `wandb_entity` and `wandb_project` not set. Disabling wandb.
# [WARNING] 10-Jan-26 20:22:53 - Label noise is not available with multi-label datasets. If this is not multi-label, ignore this warning.
# [INFO] 10-Jan-26 20:22:55 - Loading pretrained weights from Hugging Face hub (timm/vit_base_patch16_224.augreg2_in21k_ft_in1k)
# [INFO] 10-Jan-26 20:22:55 - [timm/vit_base_patch16_224.augreg2_in21k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# [INFO] 10-Jan-26 20:22:55 - Missing keys (head.weight, head.bias) discovered while loading pretrained weights. This is expected if model is being adapted.
# [INFO] 10-Jan-26 20:22:56 - Loading pretrained weights from Hugging Face hub (timm/vit_base_patch16_224.augreg2_in21k_ft_in1k)
# [INFO] 10-Jan-26 20:22:57 - [timm/vit_base_patch16_224.augreg2_in21k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# [INFO] 10-Jan-26 20:22:57 - Missing keys (head.weight, head.bias) discovered while loading pretrained weights. This is expected if model is being adapted.
# [INFO] 10-Jan-26 20:22:57 - Using backbone: lear
# Using LEAR as backbone
# Use BiLORA:  True
# Apply BiLORA for:  local
# Namespace(dataset='seq-cifar100', model='LEAR', backbone='lear', load_best_args=False, dataset_config=None, model_config='default', list_datasets='seq-cifar100,seq-cifar100,seq-cifar100', transform_type='weak', ncls_per_task=5, use_bilora=1, apply_bilora_for='local', skip_task_0=1, bilora_mode='aggregate', num_classes=100, seed=None, permute_classes=False, base_path='./data/', results_path='results/', device=device(type='cuda', index=0), notes=None, eval_epochs=None, non_verbose=False, disable_log=False, num_workers=8, enable_other_metrics=False, debug_mode=False, inference_only=False, code_optimization=0, distributed='no', savecheck=None, save_checkpoint_mode='safe', loadcheck=None, ckpt_name=None, start_from=None, stop_after=None, wandb_name=None, wandb_entity=None, wandb_project=None, lr=0.03, batch_size=32, label_perc=1.0, label_perc_by_class=1.0, joint=0, eval_future=False, validation=None, validation_mode='current', fitting_mode='epochs', early_stopping_patience=5, early_stopping_metric='loss', early_stopping_freq=1, early_stopping_epsilon=1e-06, n_epochs=15, n_iters=None, optimizer='sgd', optim_wd=0.0, optim_mom=0.0, optim_nesterov=False, drop_last=False, lr_scheduler='multisteplr', scheduler_mode='epoch', lr_milestones=[35, 45], sched_multistep_lr_gamma=0.1, noise_type='symmetric', noise_rate=0.0, disable_noisy_labels_cache=False, cache_path_noisy_labels='noisy_labels', conf_jobnum='6586739a-85cd-4d2d-b28a-f786e5a708d0', conf_timestamp='2026-01-10 20:22:53.802834', conf_host='e079c60788b6', conf_git_hash='d9141df2a3954ab461ad96da8cee30a4693fe2d0', minibatch_size=32, nowand=1)
# begin task 1, dataset:seq-cifar100
# target classes:  [6, 62, 46, 19, 80]
# [INFO] 10-Jan-26 20:22:59 - Using 8 workers for the dataloader.
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# target classes:  [6, 62, 46, 19, 80]
# [INFO] 10-Jan-26 20:23:00 - Using 8 workers for the dataloader.
# Task 1 - Epoch 15: 100%|████████████████████████████████████████████████████████████████████████████████████| 1170/1170 [11:26<00:00,  1.70it/s, loss_ce=0.000564, loss_nor=-0.0323, lr=0.03, ep/h=79.8]
# Calculate distribution for task 1:  78%|███████▊  | 78/100 [00:14<00:04,  5.30it/s]
# choose experts for evaluate: [1]
# Evaluating Task 1:  20%|████████████████████                                                                                | 3/15 [00:01<00:07,  1.55it/s, acc_task_1=99]
# Accuracy for 1 task(s): 	 [Class-IL]: 98.96 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [98.95833333333334] | Task-IL [0]
# Applying BiLORA technique for current task:  1  at index:  0
# Applying BiLORA technique for current task:  1  at index:  0
# Applying BiLORA technique for current task:  1  at index:  0
# begin task 2, dataset:seq-cifar100
# target classes:  [37, 28, 94, 11, 83]
# [INFO] 10-Jan-26 20:34:46 - Using 8 workers for the dataloader.
# target classes:  [37, 28, 94, 11, 83]
# [INFO] 10-Jan-26 20:34:47 - Using 8 workers for the dataloader.
# Choose params for task 2: 100%|██████████| 50/50 [00:10<00:00,  4.94it/s, distances=[0.94]]
# load expert 1 parameters
# Create new expert 2
# Applying BiLORA technique for current task:  1  at index:  0
# Task 2 - Epoch 15: 100%|██████████████████████████████████████████████████████| 1170/1170 [17:04<00:00,  1.14it/s, loss_ce=0.00012, loss_kd=-3.24, loss_nor=-0.0303, loss_mi=0.0653, lr=0.03, ep/h=52.9]
# Calculate distribution for task 2:  78%|███████▊  | 78/100 [00:15<00:04,  5.16it/s]
# Choose expert for evaluate: 100%|████████████████████████████████████████████████████████████████████████| 30/30 [00:06<00:00,  4.37it/s, task 2=2, distance=[6.75, 2.35]]
# Evaluating:   0%|                                                                                                                                  | 0/30 [00:00<?, ?it/s]
# choose experts for evaluate: [2, 2]
# Evaluating Task 1:  10%|██████████                                                                                           | 3/30 [00:01<00:15,  1.71it/s, acc_task_1=0]
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Evaluating Task 2:  20%|████████████████████                                                                                | 6/30 [00:03<00:15,  1.55it/s, acc_task_2=99]
# Accuracy for 2 task(s): 	 [Class-IL]: 49.48 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [0.0, 98.95833333333334] | Task-IL [0, 0]
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# begin task 3, dataset:seq-cifar100
# target classes:  [81, 76, 13, 95, 91]
# [INFO] 10-Jan-26 20:52:30 - Using 8 workers for the dataloader.
# target classes:  [81, 76, 13, 95, 91]
# [INFO] 10-Jan-26 20:52:31 - Using 8 workers for the dataloader.
# Choose params for task 3: 100%|██████████| 50/50 [00:10<00:00,  4.83it/s, distances=[1.01, 3.88]]
# load expert 1 parameters
# Create new expert 3
# Applying BiLORA technique for current task:  2  at index:  0
# Task 3 - Epoch 15: 100%|████████████████████████████████████████████████████████| 1170/1170 [17:26<00:00,  1.12it/s, loss_ce=0.0055, loss_kd=-0.127, loss_nor=-0.0259, loss_mi=0.14, lr=0.03, ep/h=52.1]
# Calculate distribution for task 3:  78%|███████▊  | 78/100 [00:15<00:04,  5.10it/s]
# Choose expert for evaluate: 100%|████████████████████████████████████████████████████████████████████| 45/45 [00:10<00:00,  4.31it/s, task 3=3, distance=[6.41, 6.4, 2.3]]
# Evaluating:   0%|                                                                                                                                  | 0/45 [00:00<?, ?it/s]
# choose experts for evaluate: [3, 3, 3]
# Evaluating Task 1:   7%|██████▋                                                                                              | 3/45 [00:01<00:25,  1.63it/s, acc_task_1=0]
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# Evaluating Task 2:  13%|█████████████▍                                                                                       | 6/45 [00:04<00:24,  1.57it/s, acc_task_2=0]
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# Evaluating Task 3:  20%|███████████████████▌                                                                              | 9/45 [00:06<00:24,  1.46it/s, acc_task_3=97.9]
# Accuracy for 3 task(s): 	 [Class-IL]: 32.64 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [0.0, 0.0, 97.91666666666666] | Task-IL [0, 0, 0]
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# System stats:
# 	Initial CPU memory usage: 2649.53 MB
# 	Average CPU memory usage: 3682.09 MB
# 	Final CPU memory usage: 4234.18 MB
# 	Max CPU memory usage: 4227.26 MB
# 	Initial GPU 0 memory usage: 1082.00 MB
# 	Average GPU 0 memory usage: 6214.00 MB
# 	Final GPU 0 memory usage: 6216.00 MB
# 	Max GPU 0 memory usage: 6214.00 MB
# Logging results and arguments in ./data/results/class-il/seq-cifar100/LEAR/logs.pyd
# [INFO CMD] Running:  python main_domain.py --list_datasets seq-cifar100,seq-cifar100,seq-cifar100 --dataset seq-cifar100 --ncls_per_task 5 --model LEAR --lr 0.03 --batch_size 32 --n_epochs 15 --num_workers 8 --backbone lear --transform_type weak --use_bilora 1 --apply_bilora_for both --bilora_mode separate --skip_task_0 0
# [INFO] 10-Jan-26 21:10:44 - Running Mammoth! on e079c60788b6. (if you see this message more than once, you are probably importing something wrong)
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# [INFO] 10-Jan-26 21:10:47 - NumExpr defaulting to 4 threads.
# ...
# Create new expert 2
# Applying BiLORA technique for current task:  1  at index:  0
# Task 2 - Epoch 15: 100%|███████████████████████████████████████████████████████████| 1170/1170 [22:18<00:00,  1.14s/it, loss_ce=1.2, loss_kd=-3.11, loss_nor=-0.0269, loss_mi=0.197, lr=0.03, ep/h=40.5]
# Calculate distribution for task 2:  78%|███████▊  | 78/100 [00:15<00:04,  5.13it/s]
# Choose expert for evaluate: 100%|████████████████████████████████████████████████████████████████████████| 30/30 [00:06<00:00,  4.30it/s, task 2=2, distance=[6.52, 4.19]]
# Evaluating:   0%|                                                                                                                                  | 0/30 [00:00<?, ?it/s]
# choose experts for evaluate: [2, 2]
# Evaluating Task 1:  10%|█████████▊                                                                                        | 3/30 [00:02<00:20,  1.31it/s, acc_task_1=2.08]
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Evaluating Task 2:  20%|███████████████████▌                                                                              | 6/30 [00:04<00:19,  1.20it/s, acc_task_2=14.6]
# Accuracy for 2 task(s): 	 [Class-IL]: 8.33 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [2.083333333333333, 14.583333333333334] | Task-IL [0, 0]
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# begin task 3, dataset:seq-cifar100
# target classes:  [95, 52, 50, 15, 27]
# [INFO] 10-Jan-26 23:55:07 - Using 8 workers for the dataloader.
# target classes:  [95, 52, 50, 15, 27]
# [INFO] 10-Jan-26 23:55:08 - Using 8 workers for the dataloader.
# Choose params for task 3: 100%|██████████| 50/50 [00:10<00:00,  4.84it/s, distances=[0.69, 30.61]]
# load expert 1 parameters
# Create new expert 3
# Applying BiLORA technique for current task:  2  at index:  0
# Task 3 - Epoch 15: 100%|██████████████████████████████████████████████████████| 1170/1170 [22:44<00:00,  1.17s/it, loss_ce=0.0967, loss_kd=-2.96, loss_nor=-0.025, loss_mi=0.000953, lr=0.03, ep/h=39.8]
# Calculate distribution for task 3:  78%|███████▊  | 78/100 [00:15<00:04,  5.03it/s]
# Choose expert for evaluate: 100%|████████████████████████████████████████████████████████████████| 45/45 [00:10<00:00,  4.19it/s, task 3=3, distance=[2.41, 108.77, 2.02]]
# Evaluating:   0%|                                                                                                                                  | 0/45 [00:00<?, ?it/s]
# choose experts for evaluate: [1, 1, 3]
# Evaluating Task 1:   7%|██████▌                                                                                           | 3/45 [00:02<00:33,  1.26it/s, acc_task_1=7.29]
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Evaluating Task 2:  13%|█████████████                                                                                     | 6/45 [00:05<00:31,  1.24it/s, acc_task_2=2.08]
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Applying BiLORA technique for current task:  3  at index:  0
# Evaluating Task 3:  20%|███████████████████▌                                                                              | 9/45 [00:07<00:31,  1.16it/s, acc_task_3=78.1]
# Accuracy for 3 task(s): 	 [Class-IL]: 29.17 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [7.291666666666667, 2.083333333333333, 78.125] | Task-IL [0, 0, 0]
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# System stats:
# 	Initial CPU memory usage: 2647.82 MB
# 	Average CPU memory usage: 3848.98 MB
# 	Final CPU memory usage: 4616.60 MB
# 	Max CPU memory usage: 4575.98 MB
# 	Initial GPU 0 memory usage: 1084.00 MB
# 	Average GPU 0 memory usage: 8914.00 MB
# 	Final GPU 0 memory usage: 8914.00 MB
# 	Max GPU 0 memory usage: 8914.00 MB
# Logging results and arguments in ./data/results/class-il/seq-cifar100/LEAR/logs.pyd
# [INFO CMD] Running:  python main_domain.py --list_datasets seq-cifar100,seq-cifar100,seq-cifar100 --dataset seq-cifar100 --ncls_per_task 5 --model LEAR --lr 0.03 --batch_size 32 --n_epochs 15 --num_workers 8 --backbone lear --transform_type weak --use_bilora 1 --apply_bilora_for both --bilora_mode aggregate --skip_task_0 1
# [INFO] 11-Jan-26 00:18:41 - Running Mammoth! on e079c60788b6. (if you see this message more than once, you are probably importing something wrong)
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# [INFO] 11-Jan-26 00:18:44 - NumExpr defaulting to 4 threads.
# /usr/local/lib/python3.11/dist-packages/deeplake/util/check_latest_version.py:32: UserWarning: A newer version of deeplake (4.4.4) is available. It's recommended that you update to the latest version using `pip install -U deeplake`.
#   warnings.warn(
# [WARNING] 11-Jan-26 00:18:45 - Trying to load default configuration for model LEAR but no configuration file found in None.
# [WARNING] 11-Jan-26 00:18:45 - Default configuration file not found for dataset seq-cifar100. Using the defaults specified in the dataset class (if available).
# [INFO] 11-Jan-26 00:18:45 - `lr_scheduler` set to multisteplr, overrides default from dataset.
# [INFO] 11-Jan-26 00:18:45 - Using device cuda:0
# Loading dataset: seq-cifar100
# Loading dataset: seq-cifar100
# Loading dataset: seq-cifar100
# [INFO] 11-Jan-26 00:18:45 - `wandb_entity` and `wandb_project` not set. Disabling wandb.
# [WARNING] 11-Jan-26 00:18:45 - Label noise is not available with multi-label datasets. If this is not multi-label, ignore this warning.
# [INFO] 11-Jan-26 00:18:47 - Loading pretrained weights from Hugging Face hub (timm/vit_base_patch16_224.augreg2_in21k_ft_in1k)
# [INFO] 11-Jan-26 00:18:47 - [timm/vit_base_patch16_224.augreg2_in21k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# [INFO] 11-Jan-26 00:18:47 - Missing keys (head.weight, head.bias) discovered while loading pretrained weights. This is expected if model is being adapted.
# [INFO] 11-Jan-26 00:18:48 - Loading pretrained weights from Hugging Face hub (timm/vit_base_patch16_224.augreg2_in21k_ft_in1k)
# [INFO] 11-Jan-26 00:18:48 - [timm/vit_base_patch16_224.augreg2_in21k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# [INFO] 11-Jan-26 00:18:48 - Missing keys (head.weight, head.bias) discovered while loading pretrained weights. This is expected if model is being adapted.
# [INFO] 11-Jan-26 00:18:48 - Using backbone: lear
# Using LEAR as backbone
# Use BiLORA:  True
# Apply BiLORA for:  both
# Namespace(dataset='seq-cifar100', model='LEAR', backbone='lear', load_best_args=False, dataset_config=None, model_config='default', list_datasets='seq-cifar100,seq-cifar100,seq-cifar100', transform_type='weak', ncls_per_task=5, use_bilora=1, apply_bilora_for='both', skip_task_0=1, bilora_mode='aggregate', num_classes=100, seed=None, permute_classes=False, base_path='./data/', results_path='results/', device=device(type='cuda', index=0), notes=None, eval_epochs=None, non_verbose=False, disable_log=False, num_workers=8, enable_other_metrics=False, debug_mode=False, inference_only=False, code_optimization=0, distributed='no', savecheck=None, save_checkpoint_mode='safe', loadcheck=None, ckpt_name=None, start_from=None, stop_after=None, wandb_name=None, wandb_entity=None, wandb_project=None, lr=0.03, batch_size=32, label_perc=1.0, label_perc_by_class=1.0, joint=0, eval_future=False, validation=None, validation_mode='current', fitting_mode='epochs', early_stopping_patience=5, early_stopping_metric='loss', early_stopping_freq=1, early_stopping_epsilon=1e-06, n_epochs=15, n_iters=None, optimizer='sgd', optim_wd=0.0, optim_mom=0.0, optim_nesterov=False, drop_last=False, lr_scheduler='multisteplr', scheduler_mode='epoch', lr_milestones=[35, 45], sched_multistep_lr_gamma=0.1, noise_type='symmetric', noise_rate=0.0, disable_noisy_labels_cache=False, cache_path_noisy_labels='noisy_labels', conf_jobnum='693c6cc9-5917-4dca-83f9-475374de8f87', conf_timestamp='2026-01-11 00:18:45.689623', conf_host='e079c60788b6', conf_git_hash='d9141df2a3954ab461ad96da8cee30a4693fe2d0', minibatch_size=32, nowand=1)
# begin task 1, dataset:seq-cifar100
# target classes:  [70, 84, 44, 27, 95]
# [INFO] 11-Jan-26 00:18:51 - Using 8 workers for the dataloader.
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# target classes:  [70, 84, 44, 27, 95]
# [INFO] 11-Jan-26 00:18:52 - Using 8 workers for the dataloader.
# Task 1 - Epoch 15: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1170/1170 [11:26<00:00,  1.71it/s, loss_ce=4.5e-5, loss_nor=-0.0323, lr=0.03, ep/h=79.4]
# Calculate distribution for task 1:  78%|███████▊  | 78/100 [00:14<00:04,  5.33it/s]
# Evaluating:   0%|                                                                                                                                  | 0/15 [00:00<?, ?it/s]
# choose experts for evaluate: [1]
# Evaluating Task 1:  20%|███████████████████▌                                                                              | 3/15 [00:02<00:09,  1.25it/s, acc_task_1=33.3]
# Accuracy for 1 task(s): 	 [Class-IL]: 33.33 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [33.33333333333333] | Task-IL [0]
# Applying BiLORA technique for current task:  1  at index:  0
# Applying BiLORA technique for current task:  1  at index:  0
# Applying BiLORA technique for current task:  1  at index:  0
# begin task 2, dataset:seq-cifar100
# target classes:  [0, 44, 55, 20, 74]
# [INFO] 11-Jan-26 00:30:38 - Using 8 workers for the dataloader.
# target classes:  [0, 44, 55, 20, 74]
# [INFO] 11-Jan-26 00:30:39 - Using 8 workers for the dataloader.
# Choose params for task 2: 100%|██████████| 50/50 [00:10<00:00,  4.95it/s, distances=[0.86]]
# load expert 1 parameters
# Create new expert 2
# Applying BiLORA technique for current task:  1  at index:  0
# Task 2 - Epoch 15: 100%|████████████████████████████████████████████████████████| 1170/1170 [21:57<00:00,  1.13s/it, loss_ce=0.0601, loss_kd=-3.2, loss_nor=-0.0267, loss_mi=0.0108, lr=0.03, ep/h=41.2]
# Calculate distribution for task 2:  78%|███████▊  | 78/100 [00:15<00:04,  5.12it/s]
# Choose expert for evaluate: 100%|████████████████████████████████████████████████████████████████████████| 30/30 [00:06<00:00,  4.33it/s, task 2=2, distance=[2.82, 1.77]]
# Evaluating:   0%|                                                                                                                                  | 0/30 [00:00<?, ?it/s]
# choose experts for evaluate: [2, 2]
# Evaluating Task 1:  10%|█████████▊                                                                                        | 3/30 [00:02<00:20,  1.30it/s, acc_task_1=12.5]
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Evaluating Task 2:  20%|███████████████████▌                                                                              | 6/30 [00:05<00:20,  1.19it/s, acc_task_2=92.7]
# Accuracy for 2 task(s): 	 [Class-IL]: 52.6 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [12.5, 92.70833333333334] | Task-IL [0, 0]
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# Applying BiLORA technique for current task:  2  at index:  1
# begin task 3, dataset:seq-cifar100
# target classes:  [55, 88, 65, 60, 47]
# [INFO] 11-Jan-26 00:53:18 - Using 8 workers for the dataloader.
# target classes:  [55, 88, 65, 60, 47]
# [INFO] 11-Jan-26 00:53:18 - Using 8 workers for the dataloader.
# Choose params for task 3: 100%|██████████| 50/50 [00:10<00:00,  4.83it/s, distances=[0.97, 0.81]]
# load expert 2 parameters
# Create new expert 3
# Applying BiLORA technique for current task:  2  at index:  1
# Task 3 - Epoch 15: 100%|███████████████████████████████████████████████████████| 1170/1170 [22:44<00:00,  1.17s/it, loss_ce=0.0338, loss_kd=-0.102, loss_nor=-0.0407, loss_mi=0.00738, lr=0.03, ep/h=40]
# Calculate distribution for task 3:  78%|███████▊  | 78/100 [00:15<00:04,  5.03it/s]
# Choose expert for evaluate: 100%|███████████████████████████████████████████████████████████████████| 45/45 [00:10<00:00,  4.21it/s, task 3=3, distance=[3.11, 2.62, 1.7]]
# Evaluating:   0%|                                                                                                                                  | 0/45 [00:00<?, ?it/s]
# choose experts for evaluate: [2, 2, 3]
# Evaluating Task 1:   7%|██████▌                                                                                           | 3/45 [00:02<00:33,  1.26it/s, acc_task_1=7.29]
# Applying BiLORA technique for current task:  3  at index:  1
# Applying BiLORA technique for current task:  3  at index:  1
# Applying BiLORA technique for current task:  3  at index:  1
# Evaluating Task 2:  13%|█████████████                                                                                     | 6/45 [00:05<00:34,  1.15it/s, acc_task_2=83.3]
# Applying BiLORA technique for current task:  3  at index:  1
# Applying BiLORA technique for current task:  3  at index:  1
# Applying BiLORA technique for current task:  3  at index:  1
# Evaluating Task 3:  20%|███████████████████▌                                                                              | 9/45 [00:08<00:33,  1.08it/s, acc_task_3=91.7]
# Accuracy for 3 task(s): 	 [Class-IL]: 60.76 % 	 [Task-IL]: 0.0 %
# 	Raw accuracy values: Class-IL [7.291666666666667, 83.33333333333334, 91.66666666666666] | Task-IL [0, 0, 0]
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# Applying BiLORA technique for current task:  3  at index:  2
# System stats:
# 	Initial CPU memory usage: 2649.26 MB
# 	Average CPU memory usage: 3839.67 MB
# 	Final CPU memory usage: 4656.89 MB
# 	Max CPU memory usage: 4607.21 MB
# 	Initial GPU 0 memory usage: 1084.00 MB
# 	Average GPU 0 memory usage: 8888.00 MB
# 	Final GPU 0 memory usage: 8888.00 MB
# 	Max GPU 0 memory usage: 8888.00 MB
# Logging results and arguments in ./data/results/class-il/seq-cifar100/LEAR/logs.pyd
